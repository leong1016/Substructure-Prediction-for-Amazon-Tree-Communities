# %%
import numpy as np

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [20,10]

from scipy.sparse import load_npz, save_npz, vstack

# %%
features = load_npz('features_silico_dropped.npz')
features.shape
# Out:
# (75785, 1676)

# %%
classes = np.load('classes_silico.npy')
classes.shape
# Out:
# (75785, 71)

# %%
def plotDistribution(y):
    n_ones =  y.sum(axis=0)
    n_records =  y.shape[0]
    n_labels =  y.shape[1]
    plt.bar(np.arange(n_labels),n_ones)
    plt.ylim([0,n_records])
    plt.title('Number of \'1\'s in Each Label')
    plt.show()

# %%
plotDistribution(classes)

# %%
def duplicateMinority(x, y):

    n = y.shape[0]
    n_pos = y.sum(axis=0)
    n_neg = n - n_pos

    minValue_pos = n_pos[n_pos != 0].min()
    minValue_neg = n_neg[n_neg != 0].min()

    new_x = x.copy()
    new_y = y.copy()
    
    if minValue_pos < minValue_neg:
        minValue = minValue_pos
        minIndex = np.where(n_pos == minValue)
        ind = np.full((n), False, dtype=bool)
        for i in minIndex[0]:
            ind = ind | (y[:,i] == 1)
        new_x = vstack([new_x, x[ind]])
        new_y = np.append(new_y, y[ind], axis=0)
    else:
        minValue = minValue_neg
        minIndex = np.where(n_neg == minValue)
        ind = np.full((n), False, dtype=bool)
        for i in minIndex[0]:
            ind = ind | (y[:,i] == 0)
        new_x = vstack([new_x, x[ind]])
        new_y = np.append(new_y, y[ind], axis=0)
            
    return new_x, new_y, ind.sum()

# %%
def duplicateMinorities(x, y, threshold=0.1, max_perc=0.5):
    
    new_x = x.copy()
    new_y = y.copy()
    i = 0
    
    while True:
        
        n = new_y.shape[0]
        n_pos = new_y.sum(axis=0)
        n_neg = n - n_pos

        minValue_pos = n_pos[n_pos != 0].min()
        minValue_neg = n_neg[n_neg != 0].min()

        ratio_pos = minValue_pos / n
        ratio_neg = minValue_neg / n
        
        if (ratio_pos > threshold and ratio_neg > threshold) or i/n >= max_perc:
            break;
        else:
            new_x, new_y, i_inc = duplicateMinority(new_x, new_y)
            i = i + i_inc
            print('{},{},{}'.format(ratio_pos, ratio_neg, i/n))
        
    return new_x, new_y

# %%
new_features, new_classes = duplicateMinorities(features, classes, max_perc=0.5)
# Out:
# 2.6390446658309693e-05,0.4819687273207099,2.6390446658309693e-05
# 5.2779500442028316e-05,0.4819823980366026,0.0001319487511050708
# 6.596741209842338e-05,0.48202388020317966,0.00019790223629527012
# 0.00010554089709762533,0.4820580474934037,0.00040897097625329813
# 0.0001318982800464282,0.48214097288171365,0.0005407829481903556
# 0.00015825706222140164,0.48220926858861074,0.0006989686914778572
# 0.00021097602784883569,0.4821988976502545,0.0011208101479469395
# 0.0002504283643073679,0.4823645709766706,0.0013707657835771714
# 0.0002635428059402548,0.48246781483482454,0.00163396539682958
# 0.00031616804331502195,0.4826041707834381,0.0019497029337759686
# 0.0004214241502377096,0.48258333004095716,0.002791934995324826
# 0.0005000197376212219,0.4829137992289169,0.003289603536981723
# 0.0005260735187742487,0.4831196159663313,0.003814033011113303
# 0.0005520867564903056,0.4833913900755833,0.00436411436082813
# 0.000630608142727643,0.48367644547210215,0.004992314463260507
# 0.0008402809689489923,0.4836342151907044,0.006669730191032627
# 0.0009175153683824204,0.48429082615705243,0.0075760554703577
# 0.0009952463889580032,0.48475046815866324,0.00856435708392808
# 0.001046586166747341,0.4851580999228143,0.009602428079906853
# 0.001071629268547681,0.4856963629948117,0.01066401808701107
# 0.0011488100677536847,0.4853200349864884,0.011801412514196943
# 0.0012518092555646833,0.4859106260350246,0.013039679745465452
# 0.0014455948427427232,0.48582405417724817,0.014468971804388877
# 0.0016515813566375364,0.4865272575946733,0.01609966708281315
# 0.0016618412681926177,0.4864910481284811,0.01939680355218571
# 0.0017469170149717259,0.48777805095821636,0.021079465313992157
# 0.0019376340196863616,0.4886712997649004,0.02298033947348025
# 0.0019596720127894383,0.48963436645866637,0.024895570109844774
# 0.0020459107519687067,0.4904266817643728,0.02689278912965155
# 0.0020545746388443017,0.49118459069020864,0.028892455858747994
# 0.0021016210674697253,0.49222784647914397,0.030934836932145833
# 0.0022506681671121114,0.4914768731057942,0.03312062814102482
# 0.002449760765550239,0.4924912280701754,0.03549601275917066
# 0.0024946860641236143,0.49230592997059835,0.037903954586531244
# 0.002564655993296345,0.4935693155415614,0.04037428741921968
# 0.0027227252580257076,0.4945102260495156,0.042993731399987335
# 0.002740591058348068,0.49550391513008335,0.04561758019701945
# 0.0028716450243711977,0.49683237401916946,0.048364547778883334
# 0.002913657770800628,0.4981978021978022,0.05113971742543171
# 0.003205730242809021,0.49839087368671503,0.06060833740310806
# 0.0035224806201550386,0.49689302325581397,0.06355348837209303
# 0.0037820267213783385,0.4983376385816164,0.0671124349577921
# 0.00391553284491781,0.49646001354429603,0.07077510312134458
# 0.003924791188843781,0.49822771147878775,0.0744238529184502
# 0.004007183609641675,0.500189363859602,0.07814008038801265
# 0.004283228483469415,0.5019895109575206,0.08211143695014662
# 0.0042891934135436734,0.5039681097258066,0.08605042831352308
# 0.0044156502225922035,0.5018157250232244,0.09009856792983219
# 0.004612446398327988,0.5028527500510492,0.09431491958247751
# 0.004615182275787032,0.5051352870141206,0.09849707665267764
# 0.004617783226021447,0.502921819025743,0.10266236625685825
# 0.004715025292912061,0.5035955029557759,0.10690549809858904
# 0.004716480562204483,0.5054534306500489,0.11112028204553762
# 0.004741283197784271,0.5030806604936098,0.11533992888075204
# 0.004894116547720557,0.5007066683798022,0.11968976674103232
# 0.005137623209968384,0.5025688116049842,0.12424446717500465
# 0.005365774683719962,0.5037236626037884,0.1289751832920878
# 0.005429156410315397,0.5057282201108836,0.13371598150406036
# 0.005857453380620066,0.508214163139229,0.1447088433817641
# 0.006287174616097881,0.5052242350227288,0.14932039713232467
# 0.006292841892347455,0.5020676480503428,0.15468030115743342
# 0.006599664991624791,0.5047124511446119,0.16031267448352876
# 0.006833738254512375,0.505341631444071,0.1660953395236352
# 0.007007723922121709,0.5019116982712077,0.17197571537181705
# 0.007002724497499809,0.5050277373540644,0.1847843926777762
# 0.00707865289782353,0.5113031843147411,0.1963894553969333
# 0.007639516944193223,0.5108049156780338,0.2012874394850242
# 0.008109563582991036,0.5069321985575959,0.2078709227796374
# 0.008128122675995853,0.510898597479863,0.21432686365493187
# 0.008332727253836483,0.5069664509023658,0.2209315615032157
# 0.008325691145709899,0.5102164885779349,0.2274315036734021
# 0.008502202192995903,0.5060036583995013,0.23405581613987758
# 0.009119557397480976,0.5079796127227959,0.24120216032181904
# 0.00912751408288064,0.5100161664440852,0.24814989607285945
# 0.009234014607255866,0.5054030925988577,0.2642142132181735
# 0.009693369032031112,0.5105434931306064,0.26915710684203326
# 0.00973579792896545,0.5141585212426207,0.2763089131907481
# 0.009814445637172212,0.517951617850023,0.2932736543474927
# 0.010603098210257181,0.512793277184539,0.29823093698300496
# 0.010510454646923134,0.5074131259766351,0.305612396755711
# 0.010898179341322877,0.5114320428563539,0.31333186060639534
# 0.011345218800648298,0.5059184528253783,0.32129914592173076
# 0.011235955056179775,0.5068874243733794,0.32893078363583983
# 0.011253561253561254,0.5012553418803419,0.3365295584045584
# 0.011198760388787154,0.5065238061698831,0.34398330750809974
# 0.0111443894964129,0.5114317057881173,0.3513181723201226
# 0.01109044568437005,0.5168164910105394,0.35853654336295376
# 0.012535767815778717,0.5111476359177,0.3671395966752964
# 0.012918853451756156,0.516325191764231,0.37551305342484187
# 0.012886940348080245,0.5224940215225189,0.3836106682609273
# 0.013247639034627492,0.5161414611752361,0.39197763641133265
# 0.013171521035598705,0.5093932038834952,0.4000242718446602
# 0.013040214648481171,0.5144935637397388,0.40786405596192543
# 0.013242840589306406,0.5177162406098013,0.41585672507705285
# 0.013124217175842728,0.5231482561984114,0.4235457947269743
# 0.012984918757870811,0.5163712872807691,0.4310440151119575
# 0.013091366671972953,0.509752196423563,0.4386100561708321
# 0.013169118417311405,0.5031725603459887,0.44611136884007
# 0.013766007414737899,0.508950858898424,0.4540788443643561
# 0.014008887593793254,0.5121220951409631,0.4758942230640344
# 0.014513397254643507,0.49818228203329296,0.49196731650969805
# 0.014351925182670257,0.4911815546082489,0.4924418244299517
# 0.014230333150022744,0.4842318946846718,0.49970466627288834
# 0.014994611311559908,0.4774377957921372,0.507688085308628
# 0.015063280286492512,0.4836803471677208,0.5152512415335
# 0.014846242308866813,0.4765026541312837,0.5224512867826211
# 0.014878742093267434,0.4828548746446772,0.5296870598478834
# 0.016048448145344438,0.48402725208175623,0.53796997224325
# 0.01589430288580937,0.49138230765410024,0.5453670590572691
# 0.01601232093091478,0.48369432357111425,0.5528467706448932
# 0.015976516445706312,0.48562354130073865,0.5601104400760328
# 0.015985790408525755,0.49333333333333335,0.5672883362936649
# 0.01724941724941725,0.48557109557109557,0.5756118881118881
# 0.017598533455545372,0.4918881759853346,0.6010483501374886
# 0.01704444837967062,0.5091641579599787,0.5976569417389764
# 0.017079832847255474,0.5136464545335829,0.604720759152048
# 0.01741893720943918,0.5050207839591704,0.6119846139854379
# 0.01733104075634008,0.5118125555397809,0.6188380420551165
# 0.017087479002455098,0.5030934229228583,0.6253831244346815
# 0.017684634187243687,0.4946412509337792,0.6325610704285475
# 0.017497166198111466,0.4860556973150039,0.6390660188454067
# 0.017480921649939883,0.4776973474345447,0.6455573822786053
# 0.018039136243711625,0.469490225585669,0.652505462385507
# 0.01826908043417493,0.47644586789976645,0.6592124775545206
# 0.01816464501239979,0.48561577867422284,0.6655499876700027
# 0.01816960429928665,0.4769521128562746,0.6718457959940958
# 0.018087727723594387,0.4687638855850235,0.6779441928519814
# 0.01805733733627823,0.4604356508973562,0.7020142571848011
# 0.017564088926709926,0.45310073396447187,0.6951090309541538
# 0.01779613887344085,0.458459647171476,0.7009069507804627
# 0.017994404479702887,0.4504434922291288,0.7066460155540675
# 0.018209040756450044,0.45579101574323316,0.7123641485295957
# 0.018018160847559066,0.4637476664777389,0.7176428155258996
# 0.019793885075550813,0.4555396792643091,0.72473495894443
# 0.019669302220813877,0.4466977944573189,0.7303373789280383
# 0.019492068008821226,0.4561728002156633,0.7357413238581265
# 0.020272578032898867,0.4567830503619316,0.7419469754562248
# 0.0202153277971556,0.44770687774694123,0.7474199899931248
# 0.020689776836905708,0.4574084854899885,0.7532998147658111
# 0.020854577948003553,0.4600002074050517,0.758884713902015
# 0.02080441010151631,0.45060307054672527,0.7641862103060388
# 0.02207877505257641,0.4618000039805484,0.770690558802651
# 0.021991289164681523,0.473426110436775,0.7760335191904505
# 0.021797534439723338,0.484045627473023,0.781132303158483
# 0.021382263909349147,0.4925659338268658,0.7858510327509153
# 0.021032004430352785,0.49647032333055424,0.7904315334010868
# 0.020884865029175633,0.48624364483808863,0.7950344802922927
# 0.020504317466619182,0.4762962616986122,0.7992742919529895
# 0.020893285200208247,0.46673779842442203,0.80410828808934
# 0.020942026955084198,0.45718568746672644,0.8085936843285045
# 0.02160476885751611,0.44780768681867583,0.8136122119638604
# 0.02172815095799439,0.45914151237387035,0.818134194435788

# %%
plotDistribution(new_classes)

# %%
save_npz('features_silico_duplicated', new_features)

# %%
np.save('classes_silico_duplicated', new_classes)
