# %%
import numpy as np

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = [20,10]

# %%
features = np.load('features_silico_dropped.npy')
features.shape
# Out:
# (75711, 4184)

# %%
classes = np.load('classes_silico.npy')
classes.shape
# Out:
# (75711, 71)

# %%
def plotDistribution(y):
    n_ones =  y.sum(axis=0)
    n_records =  y.shape[0]
    n_labels =  y.shape[1]
    plt.bar(np.arange(n_labels),n_ones)
    plt.ylim([0,n_records])
    plt.title('Number of \'1\'s in Each Label')
    plt.show()

# %%
plotDistribution(classes)

# %%
def duplicateMinority(x, y):

    n = y.shape[0]
    n_pos = y.sum(axis=0)
    n_neg = n - n_pos

    minValue_pos = n_pos[n_pos != 0].min()
    minValue_neg = n_neg[n_neg != 0].min()

    new_x = x.copy()
    new_y = y.copy()
    
    if minValue_pos < minValue_neg:
        minValue = minValue_pos
        minIndex = np.where(n_pos == minValue)
        ind = np.full((n), False, dtype=bool)
        for i in minIndex[0]:
            ind = ind | (y[:,i] == 1)
        new_x = np.append(new_x, x[ind], axis=0)
        new_y = np.append(new_y, y[ind], axis=0)
    else:
        minValue = minValue_neg
        minIndex = np.where(n_neg == minValue)
        ind = np.full((n), False, dtype=bool)
        for i in minIndex[0]:
            ind = ind | (y[:,i] == 0)
        new_x = np.append(new_x, x[ind], axis=0)
        new_y = np.append(new_y, y[ind], axis=0)
            
    return new_x, new_y, ind.sum()

# %%
def duplicateMinorities(x, y, threshold=0.1, max_perc=0.5):
    
    new_x = x.copy()
    new_y = y.copy()
    i = 0
    
    while True:
        
        n = new_y.shape[0]
        n_pos = new_y.sum(axis=0)
        n_neg = n - n_pos

        minValue_pos = n_pos[n_pos != 0].min()
        minValue_neg = n_neg[n_neg != 0].min()

        ratio_pos = minValue_pos / n
        ratio_neg = minValue_neg / n
        
        if (ratio_pos > threshold and ratio_neg > threshold) or i/n >= max_perc:
            break;
        else:
            new_x, new_y, i_inc = duplicateMinority(new_x, new_y)
            i = i + i_inc
            print('{},{},{}'.format(ratio_pos, ratio_neg, i/n))
        
    return new_x, new_y

# %%
new_features, new_classes = duplicateMinorities(features, classes, max_perc=0.5)
# Out:
# 2.6416240704785303e-05,0.48208318474197936,2.6416240704785303e-05
# 5.283108581089113e-05,0.4820968657958343,0.00013207771452722783
# 6.603188019175658e-05,0.48213837640812984,0.00019809564057526974
# 0.00010564403243271796,0.48217256952697884,0.0004093706256767821
# 0.00013202714478096697,0.482255551741438,0.0005413112936019645
# 0.00015841165909810963,0.4823238990389693,0.0006996514943499842
# 0.00021118209175861888,0.48231349981521565,0.0011219048624676628
# 0.00025067285872605415,0.48247928650588423,0.0013721040688162963
# 0.0002638000395700059,0.48258260238739037,0.0016355602453340368
# 0.0003164765609547043,0.48271906111953583,0.0019516054592206764
# 0.00042183524697135473,0.48269816369844054,0.0027946585111852254
# 0.0005005070927123533,0.48302885818526664,0.0032928098204760086
# 0.0005265860112426113,0.48323481786706335,0.0038177485815089323
# 0.0005526243075749004,0.483506795963211,0.004368363574163498
# 0.0006312218087134911,0.4837920650158463,0.004997172652315138
# 0.0008410981587835618,0.483749720729127,0.006676216635344521
# 0.0009184061716894737,0.48440677521352943,0.007583410960521655
# 0.0009962117736501987,0.4848667566752743,0.008572664473253024
# 0.0010476003404701107,0.485274667714267,0.009611733123813266
# 0.0010726666230623323,0.4858133298449866,0.010674341029498333
# 0.001149920942935173,0.4854365126033949,0.011812824231970416
# 0.0012530183384454742,0.4860275402988971,0.013052274358807021
# 0.001446989349636949,0.48594073861636533,0.01448292943645631
# 0.0016531722683606259,0.48664445080836216,0.016115175340397282
# 0.0016634394209151515,0.48660801309958546,0.019415456990994034
# 0.0017485914124732854,0.4878958616669905,0.021099669710510978
# 0.001939487975174554,0.4887897595034911,0.02300232738557021
# 0.0019615434249580592,0.4897535165827849,0.024919344431539554
# 0.002047860693954303,0.4905463537775946,0.026918420442543983
# 0.002056528836390278,0.49130473901363736,0.02891993676173828
# 0.0021036159105193622,0.4923487384718,0.03096420004874232
# 0.0022528,0.4915968,0.033152
# 0.0024520759632699453,0.49261184403775177,0.03552955900946348
# 0.002497037952428879,0.4924260762106175,0.03793968888945511
# 0.0025670678239652304,0.49369035062079836,0.04041225584262095
# 0.0027252791826697597,0.494631833795997,0.043034059651924805
# 0.0027431547543801988,0.49562612191237077,0.04566025333097363
# 0.002874323966567074,0.4969554857985704,0.048409666805340194
# 0.002916368116051338,0.498321831278048,0.05118728865759073
# 0.0032087036085381598,0.498514721181204,0.06066455259892458
# 0.003525716626733374,0.49670395153381086,0.06361187322317538
# 0.0037854889589905363,0.4981505535968331,0.0671738727036556
# 0.003919103782304876,0.4962719217165182,0.07083964949902022
# 0.003928356596570054,0.4980419597588971,0.07449146196245965
# 0.004010809621051859,0.5000061140390565,0.07821078761051126
# 0.0042870887987625905,0.501808615586978,0.08218544094900557
# 0.004293042602990577,0.5037897621848434,0.08612765131762451
# 0.004419595957156485,0.5016362165360511,0.09017907816405636
# 0.004616549850322798,0.5026749540148355,0.09439882662691304
# 0.004619269293826215,0.50496032933236,0.09858430166461232
# 0.004621853744535373,0.5027457146600912,0.10275286185660341
# 0.004719162407958547,0.5034207998861709,0.1069993004256732
# 0.004720599516138549,0.50528117070868,0.11121732460022422
# 0.004745404357784695,0.5029071474716627,0.11544018323838609
# 0.004898350460024082,0.5005319211120074,0.11979331065361999
# 0.005142046115544801,0.5023965192303218,0.12435142744130855
# 0.00537037037037037,0.5035532407407407,0.12908564814814816
# 0.00543378154356235,0.505560416282925,0.13382989500828882
# 0.005862416414765962,0.5080493725382431,0.14483145552807547
# 0.006292440018107741,0.5050588501584428,0.14944545043005886
# 0.006298079085878807,0.5019006702955598,0.1548090332448603
# 0.006605123161518172,0.5045487057982029,0.16044525906388304
# 0.006839352926154974,0.5051794775000833,0.16623180521167574
# 0.0070134424313267095,0.5017478468952284,0.17211605262287308
# 0.007008399128330359,0.5048675522070982,0.18493413199881734
# 0.007084309765764209,0.5111502284041944,0.19654639898918994
# 0.0076455367315862895,0.5106537040389305,0.20144604998349502
# 0.008115905272168152,0.5067791057709582,0.2080334781092477
# 0.008134427707370252,0.5107498139354487,0.21449311823222952
# 0.008339138843542366,0.5068158422842169,0.22110155656993127
# 0.008332044341325083,0.5100696055684455,0.22760505284867233
# 0.00850863647055214,0.5058548009367682,0.23423294437683442
# 0.009126400648988491,0.5078334938903818,0.24138315672058003
# 0.009134301361603779,0.5098728834849018,0.24833442194644023
# 0.009240818927746355,0.5052577073209591,0.26440890623755275
# 0.009700383321598999,0.5104044434013925,0.2693518735821012
# 0.009723405903773146,0.5140233981560394,0.2764875648872705
# 0.009821599846537502,0.5178112411279494,0.29346825244580854
# 0.010610678406140647,0.5126519170711518,0.2984253301727057
# 0.010517889720391676,0.5072694441341822,0.30580997058714027
# 0.010905808448317152,0.5112926698966527,0.31353278190225303
# 0.011353075170842825,0.5057767653758543,0.32150341685649203
# 0.011243648419762874,0.5067479909185917,0.3291379869544849
# 0.011261180998538898,0.5011136452727986,0.33673960300773315
# 0.011206258589702929,0.5063872149980618,0.34419600380589915
# 0.011151768600801533,0.511299878027531,0.3515333681826102
# 0.011097708082026538,0.5166896432879545,0.3587540927106669
# 0.012543886559634591,0.5110185090500051,0.36736032995875517
# 0.01292711664702912,0.5162009762666218,0.37573640801211916
# 0.012895077935458141,0.5223752866496062,0.3838362856857988
# 0.013255897890212292,0.5160202775863766,0.3922055976638121
# 0.013179625012143389,0.5092694537094006,0.4002542016126421
# 0.013048133469700844,0.5143745205829711,0.40809575556123756
# 0.013250778877627479,0.5176006625389439,0.41609023149426194
# 0.013131981473553107,0.5230374031837466,0.42378079632584753
# 0.012992501075665375,0.5162579138238368,0.4312803491302477
# 0.013098913101188535,0.5096364615489636,0.43884772039471187
# 0.013176611514561653,0.5030545781238303,0.4463502283446882
# 0.013773738269415503,0.508837656099904,0.4543190718983226
# 0.014016647958365526,0.5120121871218858,0.4761432715716431
# 0.014521218137341795,0.4980678554968625,0.49221824369837275
# 0.014359440781087432,0.4910666914718427,0.49268591823938374
# 0.014237679584281493,0.48411506979587676,0.499949054104541
# 0.015002243639115672,0.4773191526411316,0.507933106067202

# %%
plotDistribution(new_classes)

# %%
np.save('features_silico_duplicated', new_features)

# %%
np.save('classes_silico_duplicated', new_classes)
