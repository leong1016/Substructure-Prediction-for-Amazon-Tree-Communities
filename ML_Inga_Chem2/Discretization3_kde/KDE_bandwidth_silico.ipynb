# %%
import numpy as np
from sklearn.neighbors.kde import KernelDensity
from scipy.signal import argrelextrema
from bisect import bisect_left
from matplotlib import pyplot as plt

# %% [markdown]
# Read data from file

# %%
data = np.load('inga_out_silico.npz')

# %%
mass = data['arr_0']
mass
# Out:
# array([ 552.293448,  338.046024,  724.221464, ...,  328.072907,
#         262.19328 ,  636.278192])

# %%
name = data['arr_1']
name
# Out:
# array(['UNPD98266', 'UNPD207163', 'UNPD3499', ..., 'UNPD98267',
#        'UNPD47332', 'UNPD101003'], dtype=object)

# %%
massabund = data['arr_2']
massabund
# Out:
# array([[  41.00329 ,    1.688456],
#        [  43.01894 ,    2.135631],
#        [  55.01894 ,    1.105409],
#        ...,
#        [ 549.23414 ,   24.377134],
#        [ 551.24979 ,   22.666363],
#        [ 591.2447  ,    5.496205]])

# %%
blockind = data['arr_3']
blockind
# Out:
# array([     0,      0,      0, ..., 220988, 220988, 220988], dtype=uint32)

# %%
values = massabund[:,0].reshape(-1,1)
values.shape
# Out:
# (5270581, 1)

# %%
x = np.arange(0, 3200, 0.1).reshape(-1,1)
x.shape
# Out:
# (32000, 1)

# %% [markdown]
# ### Plotting Kernel Density Estimation

# %%
def KDE(values, x, bandwidth, ymax=None):
    kde = KernelDensity(kernel='gaussian', bandwidth=bandwidth).fit(values)
    dens = kde.score_samples(x)
    mi_ind = argrelextrema(dens, np.less)[0]
    mi_value = x[mi_ind]
    print('number of groups: {}'.format(mi_value.size))
    if (ymax == None):
        ymax = np.exp(dens.max())
    
    plt.figure(figsize=(20,10))
    plt.plot(x, np.exp(dens), '-')
    plt.plot(values, -(ymax*0.02)-(ymax*0.02)*np.random.random(values.shape[0]), '+k')
    plt.plot(mi_value, np.zeros(mi_value.size), 'r*')
    plt.ylim([-(ymax*0.1),ymax*1.1])
    plt.show()

# %% [markdown]
# ### masses $\in [50,150]$

# %%
values1 = values[(values<150) & (values>50)].reshape(-1,1)
values1.shape
# Out:
# (1580693, 1)

# %%
x1 = np.arange(40, 160, 0.1).reshape(-1,1)
x1.shape
# Out:
# (1200, 1)

# %% [markdown]
# bandwidth=1

# %%
KDE(values1, x1, 1)
# Out:
# number of groups: 12

# %% [markdown]
# bandwidth=0.75

# %%
KDE(values1, x1, 0.75)
# Out:
# number of groups: 37

# %% [markdown]
# bandwidth=0.5

# %%
KDE(values1, x1, 0.5)
# Out:
# number of groups: 49

# %% [markdown]
# bandwidth=0.25

# %%
KDE(values1, x1, 0.25)
# Out:
# number of groups: 97

# %% [markdown]
# bandwidth=0.1

# %%
KDE(values1, x1, 0.1)
# Out:
# number of groups: 100

# %% [markdown]
# bandwidth=0.075

# %%
KDE(values1, x1, 0.075)
# Out:
# number of groups: 100

# %% [markdown]
# bandwidth=0.05

# %%
KDE(values1, x1, 0.05)
# Out:
# number of groups: 100

# %% [markdown]
# bandwidth=0.025

# %%
KDE(values1, x1, 0.025)
# Out:
# number of groups: 100

# %% [markdown]
# bandwidth=0.01

# %%
KDE(values1, x1, 0.01)
# Out:
# number of groups: 100

# %% [markdown]
# ### masses $\in [500, 550]$

# %%
values2 = values[(values>500) & (values<550)].reshape(-1,1)
values2.shape
# Out:
# (93952, 1)

# %%
x2 = np.arange(495, 555, 0.1).reshape(-1,1)
x2.shape
# Out:
# (600, 1)

# %% [markdown]
# bandwidth=1

# %%
KDE(values2, x2, 1)
# Out:
# number of groups: 17

# %% [markdown]
# bandwidth=0.75

# %%
KDE(values2, x2, 0.75)
# Out:
# number of groups: 24

# %% [markdown]
# bandwidth=0.5

# %%
KDE(values2, x2, 0.5)
# Out:
# number of groups: 24

# %% [markdown]
# bandwidth=0.25

# %%
KDE(values2, x2, 0.25)
# Out:
# number of groups: 49

# %% [markdown]
# bandwidth=0.1

# %%
KDE(values2, x2, 0.1)
# Out:
# number of groups: 50

# %% [markdown]
# bandwidth=0.075

# %%
KDE(values2, x2, 0.075)
# Out:
# number of groups: 52

# %% [markdown]
# bandwidth=0.05

# %%
KDE(values2, x2, 0.05)
# Out:
# number of groups: 65

# %% [markdown]
# bandwidth=0.025

# %%
KDE(values2, x2, 0.025)
# Out:
# number of groups: 83

# %% [markdown]
# bandwidth=0.01

# %%
KDE(values2, x2, 0.01)
# Out:
# number of groups: 93

# %% [markdown]
# ### masses $\in [1000, 1050]$

# %%
values3 = values[(values>1000) & (values<1050)].reshape(-1,1)
values3.shape
# Out:
# (9051, 1)

# %%
x3 = np.arange(995, 1055, 0.1).reshape(-1,1)
x3.shape
# Out:
# (600, 1)

# %% [markdown]
# bandwidth=1

# %%
KDE(values3, x3, 1)
# Out:
# number of groups: 6

# %% [markdown]
# bandwidth=0.75

# %%
KDE(values3, x3, 0.75)
# Out:
# number of groups: 24

# %% [markdown]
# bandwidth=0.5

# %%
KDE(values3, x3, 0.5)
# Out:
# number of groups: 24

# %% [markdown]
# bandwidth=0.25

# %%
KDE(values3, x3, 0.25)
# Out:
# number of groups: 39

# %% [markdown]
# bandwidth=0.1

# %%
KDE(values3, x3, 0.1)
# Out:
# number of groups: 59

# %% [markdown]
# bandwidth=0.075

# %%
KDE(values3, x3, 0.075)
# Out:
# number of groups: 63

# %% [markdown]
# bandwidth=0.05

# %%
KDE(values3, x3, 0.05)
# Out:
# number of groups: 87

# %% [markdown]
# bandwidth=0.025

# %%
KDE(values3, x3, 0.025)
# Out:
# number of groups: 127

# %% [markdown]
# bandwidth=0.01

# %%
KDE(values3, x3, 0.01)
# Out:
# number of groups: 137

# %% [markdown]
# ### masses $\in [1900, 2000]$

# %%
values4 = values[(values>1900) & (values<2000)].reshape(-1,1)
values4.shape
# Out:
# (275, 1)

# %%
x4 = np.arange(1890, 2010, 0.1).reshape(-1,1)
x4.shape
# Out:
# (1200, 1)

# %% [markdown]
# bandwidth=1

# %%
KDE(values4, x4, 1)
# Out:
# number of groups: 18

# %% [markdown]
# bandwidth=0.75

# %%
KDE(values4, x4, 0.75)
# Out:
# number of groups: 27

# %% [markdown]
# bandwidth=0.5

# %%
KDE(values4, x4, 0.5)
# Out:
# number of groups: 40

# %% [markdown]
# bandwidth=0.25

# %%
KDE(values4, x4, 0.25)
# Out:
# number of groups: 72

# %% [markdown]
# bandwidth=0.1

# %%
KDE(values4, x4, 0.1)
# Out:
# number of groups: 100

# %% [markdown]
# bandwidth=0.075

# %%
KDE(values4, x4, 0.075)
# Out:
# number of groups: 109

# %% [markdown]
# bandwidth=0.05

# %%
KDE(values4, x4, 0.05)
# Out:
# number of groups: 119

# %% [markdown]
# bandwidth=0.025

# %%
KDE(values4, x4, 0.025)
# Out:
# number of groups: 129

# %% [markdown]
# bandwidth=0.01

# %%
KDE(values4, x4, 0.01)
# Out:
# number of groups: 129

# %% [markdown]
# ### Scoring Kernel Density Estimate

# %%
def KDEScoring(values, bandwidth):
    kde = KernelDensity(kernel='gaussian', bandwidth=bandwidth).fit(values)
    return kde.score(values)

# %%
scores = []
for i in [1,0.5,0.1,0.05,0.01,0.005,0.001]:
    scores.append(KDEScoring(values3, i))
